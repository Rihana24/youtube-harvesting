# %%
from googleapiclient.discovery import build
import pymongo
import psycopg2
import pandas as pd
import streamlit as st

# %%
#API_CONNECTION

def Api_connect():
    Api_Id = "AIzaSyDoEI7xI2SEOF9jHvAQFp5mUK8F6VMwNsU"

    api_service_name = "youtube"
    api_version = "v3" 

    youtube = build(api_service_name,api_version,developerKey=Api_Id)

    return youtube

youtube=Api_connect()

# %%
# get channels information

def get_channel_info(channel_id):
    request= youtube.channels().list(
                    part="snippet,ContentDetails,statistics",
                    id=channel_id
    )

    response=request.execute()

    for i in response['items']:
        data=dict(Channel_Name=i["snippet"]["title"],
                Channel_Id=i["id"],
                Subscribers=i["statistics"]["subscriberCount"],
                views=i["statistics"]["viewCount"],
                Total_Videos=i["statistics"]["videoCount"],
                Channel_Description=i["snippet"]["description"],
                Playlist_Id=i["contentDetails"]["relatedPlaylists"]["uploads"])
        return data

# %%
channel_details=get_channel_info("UCXg7gy4XmPZEGr4kumPNGyQ")

# %%
channel_details
# Out:
# {'Channel_Name': 'IELTS Advantage',
#  'Channel_Id': 'UCXg7gy4XmPZEGr4kumPNGyQ',
#  'Subscribers': '1240000',
#  'views': '42897723',
#  'Total_Videos': '179',
#  'Channel_Description': 'We help people get a 7 or above on the IELTS Test. \n\nMy name is Christopher Pell and I made IELTSAdvantage.com for my students so that they would have a better understanding of the IELTS test.\n\nThe aim of this channel is to help IELTS students prepare for the exam. \n\nWe have the most successful IELTS Course in the world. If you have any questions about our VIP Course or your IELTS preparation you can email us here:\n\nchris@ieltsadvantage.com\n\nOr check out the links below. \n',
#  'Playlist_Id': 'UUXg7gy4XmPZEGr4kumPNGyQ'}

# %%
# get video ids


def get_videos_ids(channel_id):
    video_ids = []
    response = youtube.channels().list(id= channel_id,
                                    part='contentDetails').execute()
    Playlist_Id = response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

    next_page_token = None;


    while True:
        response1 = youtube.playlistItems().list(
                                        part = 'snippet',
                                        playlistId = Playlist_Id,
                                        maxResults = 50,
                                        pageToken=next_page_token).execute()


        for i in range(len(response1['items'])):
            video_ids.append(response1['items'][i]['snippet']['resourceId']['videoId'])


        next_page_token = response1.get('next_page_token')

        if next_page_token is None:
            break
    return video_ids

# %%
# get video information

def get_video_info(video_ids):
    video_data = []
    for video_id in video_ids:
        request = youtube.videos().list(
            part = "snippet,ContentDetails,statistics",
            id = video_id
        )

        response = request.execute()

        for item in response['items']:
            data = dict(Channel_Name = item['snippet']['channelTitle'],
                        Channel_Id = item['snippet']['channelId'],
                        Video_Id = item['id'],
                        Title = item['snippet']['title'],
                        Tags = item['snippet'].get('tags'),
                        Thumbnail = item['snippet']['thumbnails']['default']['url'],
                        Description = item['snippet'].get('description'),
                        Published_Date = item['snippet']['publishedAt'],
                        Duration = item['contentDetails']['duration'],
                        Views = item['statistics'].get('viewCount'),
                        Likes = item['statistics'].get('likeCount'),
                        Comments = item['statistics'].get('commentCount'),
                        Favorite_Count = item['statistics']['favoriteCount'],
                        Definition = item['contentDetails']['definition'],
                        Caption_Status = item['contentDetails']['caption']
                        )
            


            video_data.append(data)

    return video_data

# %%
video_details = get_video_info('VNQ_FEgawSQ')

# %%
print(video_details)
# Out:
# []

# %%
#get comment information

def get_comment_info(video_ids):
    Comment_data = []
    try: 
        for video_id in video_ids:
            request = youtube.commentThreads().list(
                        part = "snippet",
                        videoId = video_id,
                        maxResults = 50)
            
            response = request.execute()

            for item in response['items']:
                data = dict(Comment_Id = item['snippet']['topLevelComment']['id'],
                            Video_Id = item['snippet']['topLevelComment']['snippet']['videoId'],
                            Comment_Text = item['snippet']['topLevelComment']['snippet']['textDisplay'],
                            Comment_Author = item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                            Comment_Published = item['snippet']['topLevelComment']['snippet']['publishedAt']
                            )
                
                Comment_data.append(data)
            
    except:
        pass

    return Comment_data

# %%
# get playlist details 

def get_playlist_details(channel_id):
    next_page_token = None
    All_data = []
    while True:
        request = youtube.playlists().list(
                                part = 'snippet,contentDetails',
                                channelId = channel_id,
                                maxResults = 50,
                                pageToken = next_page_token
                                )

        response = request.execute()

        for item in response['items']:
                        data = dict(Playlist_Id = item['id'],
                                    Channel_Id = item['snippet']['channelId'],
                                    Channel_Name = item['snippet']['channelTitle'],
                                    PublishedAt =item['snippet']['publishedAt'],
                                    Video_count = item['contentDetails']['itemCount'])
                        All_data.append(data)
                        
        

        next_page_token = response.get('nextPageToken')
        if next_page_token is None:
            break
            
        return All_data

# %%
playlist_details = get_playlist_details("UChGd9JY4yMegY6PxqpBjpRA")

# %%
print(playlist_details)
# Out:
# None

# %%
#configuration error solved

from pymongo import MongoClient
import dns.resolver

dns.resolver.default_resolver=dns.resolver.Resolver(configure=False)
dns.resolver.default_resolver.nameservers=['8.8.8.8']

# %%
# upload to mongoDB


client = pymongo.MongoClient("mongodb+srv://rihanaparveen:rihanaj@cluster0.yy5gqa1.mongodb.net/?retryWrites=true&w=majority")
db = client["Youtube_project"]

# %%
def channel_details(channel_id):
    ch_details = get_channel_info(channel_id)
    pl_details = get_playlist_details(channel_id)
    vi_ids = get_videos_ids(channel_id)
    vi_details = get_video_info(vi_ids)
    com_details = get_comment_info(vi_ids)


    col1=db["channel_details"]
    col1.insert_one({"channel_information":ch_details,"playlist_information":pl_details,
                     "video_information":vi_details,"comment_information":com_details})
    
    return "upload completed successfully"

# %%
insert = channel_details("UCK-VqZSMAUhgkMnZADVBGaA")

# %%
# Table creation for channels, playlists,videos,comments

#channel table creation

def channels_table():
    mydb = psycopg2.connect(host="localhost",
                            user="postgres",
                            password="rihana",
                            database="Youtube_project",
                            port = 5432)

    mycursor = mydb.cursor()

    drop_query = '''drop table if exists channel'''
    mycursor.execute(drop_query)
    mydb.commit()

    try:
        create_query = '''create table if not exists Channel(Channel_Name varchar(100),
                                                    Channel_Id varchar(80) primary key,
                                                    Subscribers bigint,
                                                    views bigint,
                                                    Total_Videos int,
                                                    Channel_Description text,
                                                    Playlist_Id varchar(80))'''     

        mycursor.execute(create_query)  
        mydb.commit()   

    except:
        print("channels table already created")


    ch_list =[]
    db=client["Youtube_project"]
    col1=db["channel_details"]
    for ch_data in col1.find({},{"_id":0,"channel_information":1}):
        ch_list.append(ch_data["channel_information"])
    df = pd.DataFrame(ch_list)


    for index,row in df.iterrows():
        insert_query='''insert into Channel(Channel_Name,
                                            Channel_Id,
                                            Subscribers,
                                            views,
                                            Total_Videos,
                                            Channel_Description,
                                            Playlist_Id)
                                            
                                            values(%s,%s,%s,%s,%s,%s,%s)'''
        
        values=(row['Channel_Name'],
                row['Channel_Id'],
                row['Subscribers'],
                row['views'],
                row['Total_Videos'],
                row['Channel_Description'],
                row['Playlist_Id']
                )
        try:
            mycursor.execute(insert_query,values)
            mydb.commit()

        except:
            print("channel values already inserted")

# %%
# playlist table creation

def playlists_table():

    mydb = psycopg2.connect(host="localhost",
                            user="postgres",
                            password="rihana",
                            database="Youtube_project",
                            port = 5432)

    mycursor = mydb.cursor()

    drop_query = '''drop table if exists playlists'''
    mycursor.execute(drop_query)
    mydb.commit()


    create_query = '''create table if not exists playlists(Playlist_Id varchar(100) primary key,
                                                Title varchar(80),
                                                Channel_Id varchar(100),
                                                Channel_Name varchar(100),
                                                PublishedAt timestamp,
                                                Video_count int
                                                )'''     

    mycursor.execute(create_query)  
    mydb.commit()   

    pl_list =[]
    db=client["Youtube_project"]
    col1=db["channel_details"]
    for pl_data in col1.find({},{"_id":0,"playlist_information":1}):
        for i in range(len(pl_data['playlist_information'])):
            pl_list.append(pl_data['playlist_information'][i])       

    df1=pd.DataFrame(pl_list)

    for index,row in df1.iterrows():
        insert_query='''insert into playlists(Playlist_Id,
                                            Title,
                                            Channel_Id,
                                            Channel_Name,
                                            PublishedAt,
                                            Video_Count
                                            )
                                            
                                            values(%s,%s,%s,%s,%s,%s)'''
        
        values=(row['Playlist_Id'],
                row['Title'],
                row['Channel_Id'],
                row['Channel_Name'],
                row['PublishedAt'],
                row['Video_Count']
                )
        try:
            mycursor.execute(insert_query,values)
            mydb.commit()

        except:
            print("playlist values already inserted")

# %%
pl_list =[]
db=client["Youtube_project"]
col1=db["channel_details"]
for pl_data in col1.find({},{"_id":0,"playlist_information":1}):
   print(pl_data)
# Out:
# {'playlist_information': [{'Playlist_Id': 'PLeEP84ImH_LtEJnSPy8c_Pors6Sy8IyJD', 'Channel_Id': 'UCY6KjrDBN_tIRFT_QNqQbRQ', 'Channel_Name': 'Madan Gowri', 'PublishedAt': '2023-10-09T14:50:30Z', 'Video_count': 15}, {'Playlist_Id': 'PLeEP84ImH_LsS9vZhIb4b3b7g8eH6Kcqs', 'Channel_Id': 'UCY6KjrDBN_tIRFT_QNqQbRQ', 'Channel_Name': 'Madan Gowri', 'PublishedAt': '2023-09-23T14:00:38Z', 'Video_count': 2}, {'Playlist_Id': 'PLeEP84ImH_LtWFUUofsGsUfLXy6hcdgJ0', 'Channel_Id': 'UCY6KjrDBN_tIRFT_QNqQbRQ', 'Channel_Name': 'Madan Gowri', 'PublishedAt': '2023-09-18T15:56:33Z', 'Video_count': 2}, {'Playlist_Id': 'PLeEP84ImH_Ltjam6rnoXRLpQiw0x8rey9', 'Channel_Id': 'UCY6KjrDBN_tIRFT_QNqQbRQ', 'Channel_Name': 'Madan Gowri', 'PublishedAt': '2023-08-30T08:50:14Z', 'Video_count': 1}, {'Playlist_Id': 'PLeEP84ImH_LtCPWiWuggNqIfV-udIHkZk', 'Channel_Id': 'UCY6KjrDBN_tIRFT_QNqQbRQ', 'Channel_Name': 'Madan Gowri', 'PublishedAt': '2023-08-24T13:17:12Z', 'Video_count': 58}, {'Playlist_Id': 'PLeEP84ImH_LvnGRM4w-ahcRmXgkWzyLz-', 'Channel_Id': 'UCY6KjrDBN_tIRFT_QNqQbRQ', 'Channel_Name': 'Madan Gowri', 'PublishedAt': '2023-08-02T14:16:17Z', 'Video_count': 23}, {'Playlist_Id': 'PLeEP84ImH_LsekWYiHeDquQS2dsJnR05g', 'Channel_Id': 'UCY6KjrDBN_tIRFT_QNqQbRQ', 'Channel_Name': 'Madan Gowri', 'PublishedAt': '2023-07-22T14:03:43Z', 'Video_count': 5}, {'Playlist_Id': 'PLeEP84ImH_LveuecM1V0RTCTumf2KW6cv', 'Channel_Id': 'UCY6KjrDBN_tIRFT_QNqQbRQ', 'Channel_Name': 'Madan Gowri', 'PublishedAt': '2023-07-02T13:16:35Z', 'Video_count': 9}, {'Playlist_Id': 'PLeEP84ImH_Luy9gdllPtXI1PY8jbyWZwA', 'Channel_Id': 'UCY6KjrDBN_tIRFT_QNqQbRQ', 'Channel_Name': 'Madan Gowri', 'PublishedAt': '2023-07-02T13:14:04Z', 'Video_count': 1}, {'Playlist_Id': 'PLeEP84ImH_Lu_kTCiRvuvNNecDsuzigFn', 'Channel_Id': 'UCY6KjrDBN_tIRFT_QNqQbRQ', 'Channel_Name': 'Madan Gowri', 'PublishedAt': '2023-07-02T13:13:36Z', 'Video_count': 11}, {'Playlist_Id': 'PLeEP84ImH_LvvAskdM73V_iV4JNmtkLdP', 'Channel_Id': 'UCY6KjrDBN_tIRFT_QNqQbRQ', 'Channel_Name': 'Madan Gowri', 'PublishedAt': '2023-07-02T13:11:36Z', 'Video_count': 9}, {'Playlist_Id': 'PLeEP84ImH_LvcteGwKe8YqbEyW2rUsrd9', 'Channel_Id': 'UCY6KjrDBN_tIRFT_QNqQbRQ', 'Channel_Name': 'Madan Gowri', 'PublishedAt': '2023-04-23T09:42:03Z', 'Video_count': 2}, {'Playlist_Id': 'PLeEP84ImH_Lv-jOvV9JdjnnFlqSlcaaTV', 'Channel_Id': 'UCY6KjrDBN_tIRFT_QNqQbRQ', 'Channel_Name': 'Madan Gowri', 'PublishedAt': '2023-04-15T13:07:06Z', 'Video_count': 5}, {'Playlist_Id': 'PLeEP84ImH_LsMpP0nKHOKzPZmbdDIQuqx', 'Channel_Id': 'UCY6KjrDBN_tIRFT_QNqQbRQ', 'Channel_Name': 'Madan Gowri', 'PublishedAt': '2022-09-14T15:30:10Z', 'Video_count': 6}, {'Playlist_Id': 'PLeEP84ImH_LudsKXmVigCNTttFMRsv3Nf', 'Channel_Id': 'UCY6KjrDBN_tIRFT_QNqQbRQ', 'Channel_Name': 'Madan Gowri', 'PublishedAt': '2022-06-26T11:21:01Z', 'Video_count': 2}, {'Playlist_Id': 'PLeEP84ImH_Lsy2Y2-Ay28RvVAC36-pGPP', 'Channel_Id': 'UCY6KjrDBN_tIRFT_QNqQbRQ', 'Channel_Name': 'Madan Gowri', 'PublishedAt': '2021-12-12T19:07:18Z', 'Video_count': 8}, {'Playlist_Id': 'PLeEP84ImH_Lt26KZ0hG-CD_-qGsRBQMiY', 'Channel_Id': 'UCY6KjrDBN_tIRFT_QNqQbRQ', 'Channel_Name': 'Madan Gowri', 'PublishedAt': '2021-11-18T12:17:07Z', 'Video_count': 123}, {'Playlist_Id': 'PLeEP84ImH_Lvvk0iEAVvgBA-Yep9YlstL', 'Channel_Id': 'UCY6KjrDBN_tIRFT_QNqQbRQ', 'Channel_Name': 'Madan Gowri', 'PublishedAt': '2021-10-04T14:07:20Z', 'Video_count': 7}, {'Playlist_Id': 'PLeEP84ImH_Lvm2Ou-TfXDY16m3g9efylV', 'Channel_Id': 'UCY6KjrDBN_tIRFT_QNqQbRQ', 'Channel_Name': 'Madan Gowri', 'PublishedAt': '2021-08-30T14:08:32Z', 'Video_count': 18}, {'Playlist_Id': 'PLeEP84ImH_LsI5jNerqg5jmvolCeEIPSz', 'Channel_Id': 'UCY6KjrDBN_tIRFT_QNqQbRQ', 'Channel_Name': 'Madan Gowri', 'PublishedAt': '2021-06-20T09:24:43Z', 'Video_count': 24}, {'Playlist_Id': 'PLeEP84ImH_LtnqO4Y7ovWaO3LQQeluoV7', 'Channel_Id': 'UCY6KjrDBN_tIRFT_QNqQbRQ', 'Channel_Name': 'Madan Gowri', 'PublishedAt': '2021-02-04T17:12:45Z', 'Video_count': 12}, {'Playlist_Id': 'PLeEP84ImH_Ls_o0wQMLQsmdse4gTK5ZQz', 'Channel_Id': 'UCY6KjrDBN_ ...
# {'playlist_information': [{'Playlist_Id': 'PLH4rVMDDprz-7FlYbyiuuPPUuRHFVm0vf', 'Channel_Id': 'UCBnxEdpoZwstJqC1yZpOjRA', 'Channel_Name': 'Sun TV', 'PublishedAt': '2023-11-17T05:52:46Z', 'Video_count': 35}, {'Playlist_Id': 'PLH4rVMDDprz9vwfc5TbsFLERg2OmM83gc', 'Channel_Id': 'UCBnxEdpoZwstJqC1yZpOjRA', 'Channel_Name': 'Sun TV', 'PublishedAt': '2023-11-13T10:39:40Z', 'Video_count': 17}, {'Playlist_Id': 'PLH4rVMDDprz9zJSey4TV9lfIfJZAxuMlZ', 'Channel_Id': 'UCBnxEdpoZwstJqC1yZpOjRA', 'Channel_Name': 'Sun TV', 'PublishedAt': '2023-11-13T09:52:55Z', 'Video_count': 66}, {'Playlist_Id': 'PLH4rVMDDprz_zajS2Xe-Tg7DbYLh0qPQg', 'Channel_Id': 'UCBnxEdpoZwstJqC1yZpOjRA', 'Channel_Name': 'Sun TV', 'PublishedAt': '2023-11-11T16:36:09Z', 'Video_count': 1}, {'Playlist_Id': 'PLH4rVMDDprz-qHzIXVhA8ySveuT6yMvmj', 'Channel_Id': 'UCBnxEdpoZwstJqC1yZpOjRA', 'Channel_Name': 'Sun TV', 'PublishedAt': '2023-11-09T04:56:43Z', 'Video_count': 15}, {'Playlist_Id': 'PLH4rVMDDprz-k5HXKB3EB2OSOCiW6Aos6', 'Channel_Id': 'UCBnxEdpoZwstJqC1yZpOjRA', 'Channel_Name': 'Sun TV', 'PublishedAt': '2023-11-06T06:53:53Z', 'Video_count': 22}, {'Playlist_Id': 'PLH4rVMDDprz9ohbLocZfMtliTnWPW-qTa', 'Channel_Id': 'UCBnxEdpoZwstJqC1yZpOjRA', 'Channel_Name': 'Sun TV', 'PublishedAt': '2023-11-06T05:38:37Z', 'Video_count': 13}, {'Playlist_Id': 'PLH4rVMDDprz-tvxRNIaQE0ftXIDSLaLml', 'Channel_Id': 'UCBnxEdpoZwstJqC1yZpOjRA', 'Channel_Name': 'Sun TV', 'PublishedAt': '2023-11-04T08:00:23Z', 'Video_count': 3}, {'Playlist_Id': 'PLH4rVMDDprz-GYUzgGtNXFPjJTMBRR-yt', 'Channel_Id': 'UCBnxEdpoZwstJqC1yZpOjRA', 'Channel_Name': 'Sun TV', 'PublishedAt': '2023-11-02T14:12:22Z', 'Video_count': 0}, {'Playlist_Id': 'PLH4rVMDDprz_0CITgPLnTZ5tDpdfuS402', 'Channel_Id': 'UCBnxEdpoZwstJqC1yZpOjRA', 'Channel_Name': 'Sun TV', 'PublishedAt': '2023-11-02T13:22:31Z', 'Video_count': 3}, {'Playlist_Id': 'PLH4rVMDDprz8xSz0qKbUpklfv73gEyTwA', 'Channel_Id': 'UCBnxEdpoZwstJqC1yZpOjRA', 'Channel_Name': 'Sun TV', 'PublishedAt': '2023-10-31T13:45:28Z', 'Video_count': 14}, {'Playlist_Id': 'PLH4rVMDDprz9MJuE7pXjGAIGMxJeJKctZ', 'Channel_Id': 'UCBnxEdpoZwstJqC1yZpOjRA', 'Channel_Name': 'Sun TV', 'PublishedAt': '2023-10-31T13:44:41Z', 'Video_count': 3}, {'Playlist_Id': 'PLH4rVMDDprz9kfiDDQs7lVUqIrPzZO-v_', 'Channel_Id': 'UCBnxEdpoZwstJqC1yZpOjRA', 'Channel_Name': 'Sun TV', 'PublishedAt': '2023-10-31T07:19:23Z', 'Video_count': 4}, {'Playlist_Id': 'PLH4rVMDDprz9DxtamGfoYqBDkc5kotCC-', 'Channel_Id': 'UCBnxEdpoZwstJqC1yZpOjRA', 'Channel_Name': 'Sun TV', 'PublishedAt': '2023-10-24T14:30:11Z', 'Video_count': 3}, {'Playlist_Id': 'PLH4rVMDDprz-Jl5KU49be06t6mku9eaIl', 'Channel_Id': 'UCBnxEdpoZwstJqC1yZpOjRA', 'Channel_Name': 'Sun TV', 'PublishedAt': '2023-10-24T14:11:41Z', 'Video_count': 3}, {'Playlist_Id': 'PLH4rVMDDprz_pBzQHi7dAbIkXxEONCOOy', 'Channel_Id': 'UCBnxEdpoZwstJqC1yZpOjRA', 'Channel_Name': 'Sun TV', 'PublishedAt': '2023-10-24T13:28:25Z', 'Video_count': 4}, {'Playlist_Id': 'PLH4rVMDDprz888E9v-6QZdc4aiEG2NG8T', 'Channel_Id': 'UCBnxEdpoZwstJqC1yZpOjRA', 'Channel_Name': 'Sun TV', 'PublishedAt': '2023-10-21T10:21:30Z', 'Video_count': 23}, {'Playlist_Id': 'PLH4rVMDDprz8m4q2zKZiGzUGMQ0PHs01_', 'Channel_Id': 'UCBnxEdpoZwstJqC1yZpOjRA', 'Channel_Name': 'Sun TV', 'PublishedAt': '2023-10-21T07:43:18Z', 'Video_count': 0}, {'Playlist_Id': 'PLH4rVMDDprz9L69QrPVXpeDClPdX7DaJJ', 'Channel_Id': 'UCBnxEdpoZwstJqC1yZpOjRA', 'Channel_Name': 'Sun TV', 'PublishedAt': '2023-10-18T12:50:28Z', 'Video_count': 19}, {'Playlist_Id': 'PLH4rVMDDprz85jO_B_576JuZcYaKuadAs', 'Channel_Id': 'UCBnxEdpoZwstJqC1yZpOjRA', 'Channel_Name': 'Sun TV', 'PublishedAt': '2023-10-13T06:36:17Z', 'Video_count': 7}, {'Playlist_Id': 'PLH4rVMDDprz9BdL_wNQ1wo7Mmxj1-bWPv', 'Channel_Id': 'UCBnxEdpoZwstJqC1yZpOjRA', 'Channel_Name': 'Sun TV', 'PublishedAt': '2023-10-12T10:19:54Z', 'Video_count': 3}, {'Playlist_Id': 'PLH4rVMDDprz9evG_8x3OoMF1rYPMfkMX_', 'Channel_Id': 'UCBnxEdpoZwstJqC1yZpOjRA', 'Channel_Name': 'Sun TV', 'PublishedAt': '2023-10-10T09:24:46Z', 'Video_count': 44}, {'Pl ...
# {'playlist_information': [{'Playlist_Id': 'PLsSTkBgqx7otSW1ZLqWsuTuhmP8Ga5yVq', 'Channel_Id': 'UCvrhwpnp2DHYQ1CbXby9ypQ', 'Channel_Name': 'Vijay Television', 'PublishedAt': '2023-11-18T17:05:57Z', 'Video_count': 7}, {'Playlist_Id': 'PLsSTkBgqx7ouGAXxueNboWwiP1hrWQ3Il', 'Channel_Id': 'UCvrhwpnp2DHYQ1CbXby9ypQ', 'Channel_Name': 'Vijay Television', 'PublishedAt': '2023-11-14T13:25:40Z', 'Video_count': 15}, {'Playlist_Id': 'PLsSTkBgqx7ou-6PmsBRMYAGwwmWW_SPUD', 'Channel_Id': 'UCvrhwpnp2DHYQ1CbXby9ypQ', 'Channel_Name': 'Vijay Television', 'PublishedAt': '2023-11-09T07:26:09Z', 'Video_count': 6}, {'Playlist_Id': 'PLsSTkBgqx7osoeiV6EW82uaMXtCJYEjIR', 'Channel_Id': 'UCvrhwpnp2DHYQ1CbXby9ypQ', 'Channel_Name': 'Vijay Television', 'PublishedAt': '2023-11-08T13:32:52Z', 'Video_count': 3}, {'Playlist_Id': 'PLsSTkBgqx7otYlCYBe-CuwLYCENpc-i0F', 'Channel_Id': 'UCvrhwpnp2DHYQ1CbXby9ypQ', 'Channel_Name': 'Vijay Television', 'PublishedAt': '2023-10-30T11:59:08Z', 'Video_count': 49}, {'Playlist_Id': 'PLsSTkBgqx7otihOMkzO-LzRYuhfkX1k3L', 'Channel_Id': 'UCvrhwpnp2DHYQ1CbXby9ypQ', 'Channel_Name': 'Vijay Television', 'PublishedAt': '2023-10-28T14:28:18Z', 'Video_count': 26}, {'Playlist_Id': 'PLsSTkBgqx7osTsMsd9GF6l1josuNOVisK', 'Channel_Id': 'UCvrhwpnp2DHYQ1CbXby9ypQ', 'Channel_Name': 'Vijay Television', 'PublishedAt': '2023-10-28T14:27:35Z', 'Video_count': 0}, {'Playlist_Id': 'PLsSTkBgqx7ouV2Q8UgGOinQW_bZ8MrI2u', 'Channel_Id': 'UCvrhwpnp2DHYQ1CbXby9ypQ', 'Channel_Name': 'Vijay Television', 'PublishedAt': '2023-10-28T14:27:08Z', 'Video_count': 0}, {'Playlist_Id': 'PLsSTkBgqx7ovAXgNncXD9tBQwonFMIgcf', 'Channel_Id': 'UCvrhwpnp2DHYQ1CbXby9ypQ', 'Channel_Name': 'Vijay Television', 'PublishedAt': '2023-10-23T08:08:48Z', 'Video_count': 16}, {'Playlist_Id': 'PLsSTkBgqx7ouHLEzvhNOVd8EhH79WQJJz', 'Channel_Id': 'UCvrhwpnp2DHYQ1CbXby9ypQ', 'Channel_Name': 'Vijay Television', 'PublishedAt': '2023-10-23T05:51:13Z', 'Video_count': 33}, {'Playlist_Id': 'PLsSTkBgqx7ovkVJhjWfxkjFaOYvU4eSKq', 'Channel_Id': 'UCvrhwpnp2DHYQ1CbXby9ypQ', 'Channel_Name': 'Vijay Television', 'PublishedAt': '2023-10-17T07:38:44Z', 'Video_count': 1}, {'Playlist_Id': 'PLsSTkBgqx7ouq819_PdztOjB41TRrXE2F', 'Channel_Id': 'UCvrhwpnp2DHYQ1CbXby9ypQ', 'Channel_Name': 'Vijay Television', 'PublishedAt': '2023-10-14T12:16:57Z', 'Video_count': 20}, {'Playlist_Id': 'PLsSTkBgqx7otQT2r4KVXw0FW3Kpp2KMVf', 'Channel_Id': 'UCvrhwpnp2DHYQ1CbXby9ypQ', 'Channel_Name': 'Vijay Television', 'PublishedAt': '2023-10-12T06:33:01Z', 'Video_count': 4}, {'Playlist_Id': 'PLsSTkBgqx7oviQu9b-9hSm_K26Pmy-xIV', 'Channel_Id': 'UCvrhwpnp2DHYQ1CbXby9ypQ', 'Channel_Name': 'Vijay Television', 'PublishedAt': '2023-10-07T12:34:25Z', 'Video_count': 8}, {'Playlist_Id': 'PLsSTkBgqx7otgVEoQpn6hIpDx8mWNyxF5', 'Channel_Id': 'UCvrhwpnp2DHYQ1CbXby9ypQ', 'Channel_Name': 'Vijay Television', 'PublishedAt': '2023-10-06T11:38:31Z', 'Video_count': 5}, {'Playlist_Id': 'PLsSTkBgqx7otiUprPfdMdfFR4O0jSRcpw', 'Channel_Id': 'UCvrhwpnp2DHYQ1CbXby9ypQ', 'Channel_Name': 'Vijay Television', 'PublishedAt': '2023-10-05T08:04:26Z', 'Video_count': 18}, {'Playlist_Id': 'PLsSTkBgqx7ot3qEFLL7u5J1IjpeSy5F8O', 'Channel_Id': 'UCvrhwpnp2DHYQ1CbXby9ypQ', 'Channel_Name': 'Vijay Television', 'PublishedAt': '2023-10-03T14:06:43Z', 'Video_count': 39}, {'Playlist_Id': 'PLsSTkBgqx7ouyPUQlUV_5iVS2Ombj8Ydt', 'Channel_Id': 'UCvrhwpnp2DHYQ1CbXby9ypQ', 'Channel_Name': 'Vijay Television', 'PublishedAt': '2023-10-03T10:20:54Z', 'Video_count': 5}, {'Playlist_Id': 'PLsSTkBgqx7ot9b9OtRNdGXHDIcXki8IAI', 'Channel_Id': 'UCvrhwpnp2DHYQ1CbXby9ypQ', 'Channel_Name': 'Vijay Television', 'PublishedAt': '2023-08-18T12:08:19Z', 'Video_count': 178}, {'Playlist_Id': 'PLsSTkBgqx7osBUGsWJUTFfR3BR1YX51yG', 'Channel_Id': 'UCvrhwpnp2DHYQ1CbXby9ypQ', 'Channel_Name': 'Vijay Television', 'PublishedAt': '2023-08-18T10:24:27Z', 'Video_count': 26}, {'Playlist_Id': 'PLsSTkBgqx7ottkqwGRYswe_88wCqRnIno', 'Channel_Id': 'UCvrhwpnp2DHYQ1CbXby9ypQ', 'Channel_Name': 'Vijay Television', 'PublishedAt': '2023-08-17T15:4 ...
# {'playlist_information': [{'Playlist_Id': 'PLljM0HW-KjfoCNPWywPS7GGgFM1rufLKG', 'Channel_Id': 'UCK-VqZSMAUhgkMnZADVBGaA', 'Channel_Name': 'Jaya TV', 'PublishedAt': '2023-11-12T01:09:44Z', 'Video_count': 10}, {'Playlist_Id': 'PLljM0HW-KjfoYudLz8cQ2lNEXvOxh5SCg', 'Channel_Id': 'UCK-VqZSMAUhgkMnZADVBGaA', 'Channel_Name': 'Jaya TV', 'PublishedAt': '2023-11-07T07:16:26Z', 'Video_count': 10}, {'Playlist_Id': 'PLljM0HW-KjfrHdBJSYw5urLCDSwy5eVZq', 'Channel_Id': 'UCK-VqZSMAUhgkMnZADVBGaA', 'Channel_Name': 'Jaya TV', 'PublishedAt': '2023-10-20T08:43:08Z', 'Video_count': 9}, {'Playlist_Id': 'PLljM0HW-KjfqrlNYE9qpVhWy4032G1Nx1', 'Channel_Id': 'UCK-VqZSMAUhgkMnZADVBGaA', 'Channel_Name': 'Jaya TV', 'PublishedAt': '2023-10-18T15:21:39Z', 'Video_count': 1}, {'Playlist_Id': 'PLljM0HW-Kjfoce3mOiFqoYi98ns5Us2ps', 'Channel_Id': 'UCK-VqZSMAUhgkMnZADVBGaA', 'Channel_Name': 'Jaya TV', 'PublishedAt': '2023-10-18T15:20:54Z', 'Video_count': 0}, {'Playlist_Id': 'PLljM0HW-KjfrU97xuLv1qOPv4Ee958N70', 'Channel_Id': 'UCK-VqZSMAUhgkMnZADVBGaA', 'Channel_Name': 'Jaya TV', 'PublishedAt': '2023-10-17T13:23:32Z', 'Video_count': 12}, {'Playlist_Id': 'PLljM0HW-Kjfq3ZT1xQfmJ1fBayck09MM8', 'Channel_Id': 'UCK-VqZSMAUhgkMnZADVBGaA', 'Channel_Name': 'Jaya TV', 'PublishedAt': '2023-10-17T09:24:24Z', 'Video_count': 5}, {'Playlist_Id': 'PLljM0HW-KjfroKJEpmo42xTVuIEwp4B2k', 'Channel_Id': 'UCK-VqZSMAUhgkMnZADVBGaA', 'Channel_Name': 'Jaya TV', 'PublishedAt': '2023-10-17T07:10:25Z', 'Video_count': 22}, {'Playlist_Id': 'PLljM0HW-KjfotmcJ6NHisXqdXvwdQVYO6', 'Channel_Id': 'UCK-VqZSMAUhgkMnZADVBGaA', 'Channel_Name': 'Jaya TV', 'PublishedAt': '2023-10-16T08:25:15Z', 'Video_count': 2}, {'Playlist_Id': 'PLljM0HW-KjfowyGll2Oqjk_hRswlrqPvg', 'Channel_Id': 'UCK-VqZSMAUhgkMnZADVBGaA', 'Channel_Name': 'Jaya TV', 'PublishedAt': '2023-10-15T11:29:57Z', 'Video_count': 2}, {'Playlist_Id': 'PLljM0HW-KjfpwvF5bp9LX_8cKOFbWNmO8', 'Channel_Id': 'UCK-VqZSMAUhgkMnZADVBGaA', 'Channel_Name': 'Jaya TV', 'PublishedAt': '2023-10-11T14:48:50Z', 'Video_count': 9}, {'Playlist_Id': 'PLljM0HW-Kjfp6CS16HY7KrOrJWAhbBwRb', 'Channel_Id': 'UCK-VqZSMAUhgkMnZADVBGaA', 'Channel_Name': 'Jaya TV', 'PublishedAt': '2023-10-10T04:15:18Z', 'Video_count': 4}, {'Playlist_Id': 'PLljM0HW-KjfpyYQwREKrfsex5qvF6x9--', 'Channel_Id': 'UCK-VqZSMAUhgkMnZADVBGaA', 'Channel_Name': 'Jaya TV', 'PublishedAt': '2023-10-03T00:57:13Z', 'Video_count': 23}, {'Playlist_Id': 'PLljM0HW-KjfrRdCkRRFBeU2z7ihNZsCD_', 'Channel_Id': 'UCK-VqZSMAUhgkMnZADVBGaA', 'Channel_Name': 'Jaya TV', 'PublishedAt': '2023-10-02T05:11:59Z', 'Video_count': 12}, {'Playlist_Id': 'PLljM0HW-KjfrJ14YJ8NUlgs9D2TdOoIzw', 'Channel_Id': 'UCK-VqZSMAUhgkMnZADVBGaA', 'Channel_Name': 'Jaya TV', 'PublishedAt': '2023-09-29T06:54:29Z', 'Video_count': 5}, {'Playlist_Id': 'PLljM0HW-Kjfr3Zv7J-oSBqm3QFEg_4hXl', 'Channel_Id': 'UCK-VqZSMAUhgkMnZADVBGaA', 'Channel_Name': 'Jaya TV', 'PublishedAt': '2023-09-15T09:52:25Z', 'Video_count': 5}, {'Playlist_Id': 'PLljM0HW-Kjfra5-ba70Tn5E_usOuplRFe', 'Channel_Id': 'UCK-VqZSMAUhgkMnZADVBGaA', 'Channel_Name': 'Jaya TV', 'PublishedAt': '2023-09-14T14:47:06Z', 'Video_count': 14}, {'Playlist_Id': 'PLljM0HW-Kjfq8TRoZdNqS0yRtqajs8ZnJ', 'Channel_Id': 'UCK-VqZSMAUhgkMnZADVBGaA', 'Channel_Name': 'Jaya TV', 'PublishedAt': '2023-09-05T12:35:27Z', 'Video_count': 1}, {'Playlist_Id': 'PLljM0HW-Kjfr2rRBVrKrPd6egP08D34DA', 'Channel_Id': 'UCK-VqZSMAUhgkMnZADVBGaA', 'Channel_Name': 'Jaya TV', 'PublishedAt': '2023-08-29T07:00:23Z', 'Video_count': 27}, {'Playlist_Id': 'PLljM0HW-Kjfp5w4pgFnHTqEMCFyFRWU-Z', 'Channel_Id': 'UCK-VqZSMAUhgkMnZADVBGaA', 'Channel_Name': 'Jaya TV', 'PublishedAt': '2023-08-28T10:24:11Z', 'Video_count': 12}, {'Playlist_Id': 'PLljM0HW-Kjfqn9sH0ROhDfGMzNr4TsD0u', 'Channel_Id': 'UCK-VqZSMAUhgkMnZADVBGaA', 'Channel_Name': 'Jaya TV', 'PublishedAt': '2023-08-22T05:14:42Z', 'Video_count': 24}, {'Playlist_Id': 'PLljM0HW-KjfqkEeXqIMbts4vFsfUikFok', 'Channel_Id': 'UCK-VqZSMAUhgkMnZADVBGaA', 'Channel_Name': 'Jaya TV', 'PublishedAt': '2023-08-20T10:22:32Z', ' ...

# %%
# video table creation

def videos_table():
        mydb = psycopg2.connect(host="localhost",
                                user="postgres",
                                password="rihana",
                                database="Youtube_project",
                                port = 5432)

        mycursor = mydb.cursor()

        drop_query = '''drop table if exists videos'''
        mycursor.execute(drop_query)
        mydb.commit()


        create_query = '''create table if not exists videos(Channel_Name varchar(100),
                                Channel_Id varchar(100),
                                Video_Id varchar(30) primary key,
                                Title varchar(150),
                                Tags text,
                                Thumbnail varchar(200),
                                Description text,
                                Published_Date timestamp,
                                Duration interval,
                                Views bigint,
                                Likes bigint,
                                Comments int,
                                Favorite_Count int,
                                Definition varchar(20),
                                Caption_Status varchar(50)
                                )'''     

        mycursor.execute(create_query)  
        mydb.commit()   

        vid_list =[]
        db=client["Youtube_project"]
        col1=db["channel_details"]
        for vid_data in col1.find({},{"_id":0,"video_information":1}):
                for i in range(len(vid_data['video_information'])):
                        vid_list.append(vid_data['video_information'][i])       

        df2=pd.DataFrame(vid_list)


        for index,row in df2.iterrows():
                insert_query='''insert into videos(Channel_Name,
                                Channel_Id,
                                Video_Id,
                                Title,
                                Tags,
                                Thumbnail,
                                Description,
                                Published_Date,
                                Duration,
                                Views,
                                Likes,
                                Comments,
                                Favorite_Count,
                                Definition,
                                Caption_Status
                                )
                                values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''
                
                values=(row['Channel_Name'],
                        row['Channel_Id'],
                        row['Video_Id'],
                        row['Title'],
                        row['Tags'],
                        row['Thumbnail'],
                        row['Description'],
                        row['Published_Date'],
                        row['Duration'],
                        row['Views'],
                        row['Likes'],
                        row['Comments'],
                        row['Favorite_Count'],
                        row['Definition'],
                        row['Caption_Status']
                        )
                
        
                mycursor.execute(insert_query,values)
                mydb.commit()

# %%
# comment table creation

def comments_table():

        mydb = psycopg2.connect(host="localhost",
                                user="postgres",
                                password="rihana",
                                database="Youtube_project",
                                port = 5432)

        mycursor = mydb.cursor()

        drop_query = '''drop table if exists comments'''
        mycursor.execute(drop_query)
        mydb.commit()


        create_query = '''create table if not exists comments(Comment_Id varchar(100) primary key,
                                Video_Id varchar(50),
                                Comment_Text text,
                                Comment_Author varchar(50),
                                Comment_Published timestamp
                                )'''     

        mycursor.execute(create_query)  
        mydb.commit()   



        com_list =[]
        db=client["Youtube_project"]
        col1=db["channel_details"]
        for com_data in col1.find({},{"_id":0,"comment_information":1}):
                for i in range(len(com_data['comment_information'])):
                        com_list.append(com_data['comment_information'][i])       

        df3=pd.DataFrame(com_list)


        for index,row in df3.iterrows():
                insert_query='''insert into comments(Comment_Id,
                                Video_Id,
                                Comment_Text,
                                Comment_Author,
                                Comment_Published
                                )
                                                
                                values(%s,%s,%s,%s,%s)'''
                
                values=(row['Comment_Id'],
                        row['Video_Id'],
                        row['Comment_Text'],
                        row['Comment_Author'],
                        row['Comment_Published']
                        )
                try:        
                        mycursor.execute(insert_query,values)
                        mydb.commit()

                except:
                        print("channel values already inserted")

# %%
def tables():
    channels_table()
    playlists_table()
    videos_table()
    comments_table()

    return "tables created successfully"

# %%
Tables = tables()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\pc\Desktop\New folder\.venv\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Title'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\pc\Desktop\New folder\testyoutube.ipynb Cell 24 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pc/Desktop/New%20folder/testyoutube.ipynb#X51sZmlsZQ%3D%3D?line=0'>1</a> Tables = tables()
#
# c:\Users\pc\Desktop\New folder\testyoutube.ipynb Cell 24 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/pc/Desktop/New%20folder/testyoutube.ipynb#X51sZmlsZQ%3D%3D?line=0'>1</a> def tables():
#       <a href='vscode-notebook-cell:/c%3A/Users/pc/Desktop/New%20folder/testyoutube.ipynb#X51sZmlsZQ%3D%3D?line=1'>2</a>     channels_table()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pc/Desktop/New%20folder/testyoutube.ipynb#X51sZmlsZQ%3D%3D?line=2'>3</a>     playlists_table()
#       <a href='vscode-notebook-cell:/c%3A/Users/pc/Desktop/New%20folder/testyoutube.ipynb#X51sZmlsZQ%3D%3D?line=3'>4</a>     videos_table()
#       <a href='vscode-notebook-cell:/c%3A/Users/pc/Desktop/New%20folder/testyoutube.ipynb#X51sZmlsZQ%3D%3D?line=4'>5</a>     comments_table()
#
# c:\Users\pc\Desktop\New folder\testyoutube.ipynb Cell 24 line 5
#      <a href='vscode-notebook-cell:/c%3A/Users/pc/Desktop/New%20folder/testyoutube.ipynb#X51sZmlsZQ%3D%3D?line=37'>38</a> for index,row in df1.iterrows():
#      <a href='vscode-notebook-cell:/c%3A/Users/pc/Desktop/New%20folder/testyoutube.ipynb#X51sZmlsZQ%3D%3D?line=38'>39</a>     insert_query='''insert into playlists(Playlist_Id,
#      <a href='vscode-notebook-cell:/c%3A/Users/pc/Desktop/New%20folder/testyoutube.ipynb#X51sZmlsZQ%3D%3D?line=39'>40</a>                                         Title,
#      <a href='vscode-notebook-cell:/c%3A/Users/pc/Desktop/New%20folder/testyoutube.ipynb#X51sZmlsZQ%3D%3D?line=40'>41</a>                                         Channel_Id,
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/pc/Desktop/New%20folder/testyoutube.ipynb#X51sZmlsZQ%3D%3D?line=45'>46</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/pc/Desktop/New%20folder/testyoutube.ipynb#X51sZmlsZQ%3D%3D?line=46'>47</a>                                         values(%s,%s,%s,%s,%s,%s)'''
#      <a href='vscode-notebook-cell:/c%3A/Users/pc/Desktop/New%20folder/testyoutube.ipynb#X51sZmlsZQ%3D%3D?line=48'>49</a>     values=(row['Playlist_Id'],
# ---> <a href='vscode-notebook-cell:/c%3A/Users/pc/Desktop/New%20folder/testyoutube.ipynb#X51sZmlsZQ%3D%3D?line=49'>50</a>             row['Title'],
#      <a href='vscode-notebook-cell:/c%3A/Users/pc/Desktop/New%20folder/testyoutube.ipynb#X51sZmlsZQ%3D%3D?line=50'>51</a>             row['Channel_Id'],
#      <a href='vscode-notebook-cell:/c%3A/Users/pc/Desktop/New%20folder/testyoutube.ipynb#X51sZmlsZQ%3D%3D?line=51'>52</a>             row['Channel_Name'],
#      <a href='vscode-notebook-cell:/c%3A/Users/pc/Desktop/New%20folder/testyoutube.ipynb#X51sZmlsZQ%3D%3D?line=52'>53</a>             row['PublishedAt'],
#      <a href='vscode-notebook-cell:/c%3A/Users/pc/Desktop/New%20folder/testyoutube.ipynb#X51sZmlsZQ%3D%3D?line=53'>54</a>             row['Video_Count']
#      <a href='vscode-notebook-cell:/c%3A/Users/pc/Desktop/New%20folder/testyoutube.ipynb#X51sZmlsZQ%3D%3D?line=54'>55</a>             )
#      <a href='vscode-notebook-cell:/c%3A/Users/pc/Desktop/New%20folder/testyoutube.ipynb#X51sZmlsZQ%3D%3D?line=55'>56</a>     try:
#      <a href='vscode-notebook-cell:/c%3A/Users/pc/Desktop/New%20folder/testyoutube.ipynb#X51sZmlsZQ%3D%3D?line=56'>57</a>         mycursor.execute(insert_query,values)
#
# File c:\Users\pc\Desktop\New folder\.venv\Lib\site-packages\pandas\core\series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# File c:\Users\pc\Desktop\New folder\.venv\Lib\site-packages\pandas\core\series.py:1156, in Series._get_value(self, label, takeable)
#    1153     return self._values[label]
#    1155 # Similar to Index.get_value, but we do not fall back to positional
# -> 1156 loc = self.index.get_loc(label)
#    1158 if is_integer(loc):
#    1159     return self._values[loc]
#
# File c:\Users\pc\Desktop\New folder\.venv\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'Title'

# %%
def show_channels_table():

    ch_list =[]
    db=client["Youtube_project"]
    col1=db["channel_details"]
    for ch_data in col1.find({},{"_id":0,"channel_information":1}):
        ch_list.append(ch_data["channel_information"])
    df = st.dataframe(ch_list)

    return df

# %%
def show_playlists_table():
    pl_list =[]
    db=client["Youtube_project"]
    col1=db["channel_details"]
    for pl_data in col1.find({},{"_id":0,"playlist_information":1}):
        for i in range(len(pl_data['playlist_information'])):
            pl_list.append(pl_data['playlist_information'][i])       

    df1=st.dataframe(pl_list)

    return df1

# %%
df1
# Out:
# DeltaGenerator()

# %%
def show_videos_table():
        vid_list =[]
        db=client["Youtube_project"]
        col1=db["channel_details"]
        for vid_data in col1.find({},{"_id":0,"video_information":1}):
                for i in range(len(vid_data['video_information'])):
                        vid_list.append(vid_data['video_information'][i])       

        df2=st.dataframe(vid_list)

        return df2

# %%
def show_comments_table():
    com_list =[]
    db=client["Youtube_project"]
    col1=db["channel_details"]
    for com_data in col1.find({},{"_id":0,"comment_information":1}):
        for i in range(len(com_data['comment_information'])):
                com_list.append(com_data['comment_information'][i])       

    df3=st.dataframe(com_list)

    return df3

# %%
# streamlit code

with st.sidebar:
    st.title(":pink[YOUTUBE DATA HARVESTING AND WAREHOUSING]")
    st.header("skills take away")
    st.caption("python")
    st.caption("Data collection")
    st.caption("Mongo db")
    st.caption("API")
    st.caption("Postgre SQL")

    channel_id = st.text_input("Enter the channel id")

    if st.button("collect and store data"):
            ch_ids = []
            db=client["Youtube_project"]
            col1=db["channel_details"]
            for ch_data in col1.find({},{"_id":0,"channel_information":1}):
                ch_ids.append(ch_data["channel_information"]["Channel_Id"])
            
            if channel_id in ch_ids:
                 st.success("Already exists")
            else:
                 insert = channel_details

    if st.button("Migrate to sql"):
         Table = tables()
         st.success(Table)
                 

    show_table = st.radio("select the table to view",("CHANNELS","PLAYLISTS","VIDEOS","COMMENTS"))
    
    if show_table=="CHANNELS":
         show_channels_table()

    elif show_table=="PLAYLISTS":
         show_playlists_table()

    elif show_table=="VIDEOS":
         show_videos_table()

    elif show_table=="COMMENTS":
         show_comments_table()

# %%
#SQL CONNECTION

mydb = psycopg2.connect(host="localhost",
                            user="postgres",
                            password="rihana",
                            database="Youtube_project",
                            port = 5432)
mycursor = mydb.cursor()


question = st.selectbox("select your question",("1. All the channels and videos name",
                                                "2. channels with most number of videos",
                                                "3. 10 most viwed videos",
                                                "4. comments in each videos",
                                                "5. videos with highest likes",
                                                "6. likes of all videos",
                                                "7. views of each channel",
                                                "8. videos published in the year of 2022",
                                                "9. average duration of all videos in each channel",
                                                "10. videos with highest number of comments"))

if question=="1. All the channels and videos name":
    query1 = '''select title as videos,channel_name as channelname from videos '''
    mycursor.execute(query1)
    mydb.commit()
    t1 = mycursor.fetchall()
    df = pd.DataFrame(t1,columns=["video title","channel name"])
    st.write(df)


elif question=="2. channels with most number of videos":
    query2 = '''select channel_name as channelname,total_videos as no_videos from channel
                    order by total_videos desc'''
    mycursor.execute(query2)
    mydb.commit()
    t2 = mycursor.fetchall()
    df2 = pd.DataFrame(t2,columns=["channel name","No of videos"])
    st.write(df2)

elif question=="3. 10 most viwed videos":
    query3 = '''select views as views,channel_name as channel name,title as videotitle from videos
                    where views is not null order by views desc limit 10'''
    mycursor.execute(query3)
    mydb.commit()
    t3 = mycursor.fetchall()
    df3 = pd.DataFrame(t3,columns=["views","channel name","videotitle"])
    st.write(df3)

elif question=="4. comments in each videos":
    query4 = '''select comments as no_comments,title as videotitle from videos where comments is not null'''
    mycursor.execute(query4)
    mydb.commit()
    t4 = mycursor.fetchall()
    df4 = pd.DataFrame(t4,columns=["no of comments","videotitle"])
    st.write(df4)

elif question=="5. videos with highest likes":
    query5 = '''select title as videotitle,channel_name as channelname,likes as likecount
                    from videos where likes is not null order by likes desc'''
    mycursor.execute(query5)
    mydb.commit()
    t5 = mycursor.fetchall()
    df5 = pd.DataFrame(t5,columns=["videotitle","channelname","likescount"])
    st.write(df5)

elif question=="6. likes of all videos":
    query6 = '''select likes as likecount,title as videotitle from videos'''
    mycursor.execute(query6)
    mydb.commit()
    t6 = mycursor.fetchall()
    df6 = pd.DataFrame(t6,columns=["likecount","videotitle"])
    st.write(df6)

elif question=="7. views of each channel":
    query7 = '''select channel_name as channelname,views as totalviews from channel'''
    mycursor.execute(query7)
    mydb.commit()
    t7 = mycursor.fetchall()
    df7 = pd.DataFrame(t7,columns=["channel name","totalviews"])
    st.write(df7)

elif question=="8. videos published in the year of 2022":
    query8 = '''select title as video_title,published_date as videorelease,
                    channel_name as channelname from videos where extract(year from published_date)=2022'''
    mycursor.execute(query8)
    mydb.commit()
    t8 = mycursor.fetchall()
    df8 = pd.DataFrame(t8,columns=["videotitle","published_date","channelname"])
    st.write(df8)


elif question=="9. average duration of all videos in each channel":
    query9 = '''select channel_name as channelname,AVG(duration) as averageduration from videos 
                    group by channel_name'''
    mycursor.execute(query9)
    mydb.commit()
    t9 = mycursor.fetchall()
    df9 = pd.DataFrame(t9,columns=["channelname","averageduration"])
    df9
   
    T9=[]
    for index,row in df9.iterrows():
        channel_title = row["channelname"],
        average_duration = row["averageduration"]
        average_duration_str = str(average_duration)
        T9.append(dict(channeltitle=channel_title,avgduration=average_duration_str))
    df1 = pd.DataFrame(T9)
    st.write(df1)

elif question=="10. videos with highest number of comments":
    query10 = '''select title as videotitle,channel_name as channelname,comments as comments
                    from videos where comments is not null order by comments desc'''
    mycursor.execute(query10)
    mydb.commit()
    t10 = mycursor.fetchall()
    df10 = pd.DataFrame(t10,columns=["video title","channel name","comments"])
    st.write(df10)
